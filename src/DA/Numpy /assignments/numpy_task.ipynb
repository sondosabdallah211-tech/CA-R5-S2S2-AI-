# %%
import numpy as np

# %% [markdown]
# Task 1

# %%
def array_factory(mode , shape, value=None):
    """
        Creates various NumPy arrays based on the mode.
        - 'zeros': Array filled with 0.
        - 'ones': Array filled with 1.
        - 'full': Array filled with a specified 'value'.
        - 'identity': A square identity matrix of size 'shape'.
   """
    if mode=="zeros":
        return np.zeros(shape)
    
    elif mode=="ones":
        return np.ones(shape)
    elif mode=="full":
        return np.full(shape, value)
    elif mode=="identity":
        return np.identity(shape)
    else:
        raise ValueError("invalid mode")

# %%
array_factory("identity", 3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %% [markdown]
# Task 2

# %%
def secure_reshape_and_stack(data1, data2, new_shape):
    """
        1. Validates and converts inputs to NumPy arrays.
        2. Reshapes the first dataset to a specific dimension.
        3. Vertically stacks both datasets into one matrix.
    """
    
    try:
        #convert inputs to ndarray
        
        arr1 = np.array(data1)
        arr2 = np.array(data2)
        
        #reshape arr1 to new_shape
    
        reshaped_arr1 = arr1.reshape(new_shape)
        
        #vertical stacking
        
        combined_dataset = np.vstack((reshaped_arr1, arr2))
        
        return combined_dataset
    
    
    except ValueError as e:
        raise ValueError(f"company-grade Error:{e}")

# %%
data1 = [1, 2, 3, 4, 5, 6]
data2 = [[7, 8, 9]]
new_shape = (2, 3)
 
result = secure_reshape_and_stack(data1, data2, new_shape)

print(result)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %%
data1 = [1, 2, 3, 4, 5, 6]
data2 = [[7, 8]]
new_shape = (2, 3)

result = secure_reshape_and_stack(data1, data2, new_shape)
print(result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 20, in secure_reshape_and_stack(data1, data2, new_shape)
#      18 #vertical stacking
# ---> 20 combined_dataset = np.vstack((reshaped_arr1, arr2))
#      22 return combined_dataset
#
# File ~/anaconda3/lib/python3.13/site-packages/numpy/_core/shape_base.py:291, in vstack(tup, dtype, casting)
#     290     arrs = (arrs,)
# --> 291 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 3 and the array at index 1 has size 2
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 5
#       2 data2 = [[7, 8]]
#       3 new_shape = (2, 3)
# ----> 5 result = secure_reshape_and_stack(data1, data2, new_shape)
#       6 print(result)
#
# Cell In[13], line 26, in secure_reshape_and_stack(data1, data2, new_shape)
#      22     return combined_dataset
#      25 except ValueError as e:
# ---> 26     raise ValueError(f"company-grade Error:{e}")
#
# ValueError: company-grade Error:all the input array dimensions except for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 3 and the array at index 1 has size 2
