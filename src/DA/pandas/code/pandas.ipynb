# %%
import pandas as pd

# %%
s= pd.Series([1,2,3,4,5], index=["A","B","C","D","E"])
s
# Out:
# A    1
# B    2
# C    3
# D    4
# E    5
# dtype: int64

# %%
data = [[1,444,"abc"],
         [2,222,"awe"],
         [3,333,"rgd"],
         [4,444,"kfk"]]

'''
 data = { "col1":[1,2,3,4],
        
         "col2":[444,222,333,444],
        
         "col3":["abc","awe","rgd","kfk"] }
        
'''

df = pd.DataFrame(data, columns= ["col1","col2","col3"])
df
# Out:
#    col1  col2 col3
# 0     1   444  abc
# 1     2   222  awe
# 2     3   333  rgd
# 3     4   444  kfk

# %%
df = pd.DataFrame([[1,444,"abc"],
         [2,222,"awe"],
         [3,333,"rgd"],
         [4,444,"kfk"]])

display(df)
columns = ["col1","col2","col3"]
df.columns=columns
display(df)
df.columns
# Out:
#    0    1    2
# 0  1  444  abc
# 1  2  222  awe
# 2  3  333  rgd
# 3  4  444  kfk
#    col1  col2 col3
# 0     1   444  abc
# 1     2   222  awe
# 2     3   333  rgd
# 3     4   444  kfk
# Index(['col1', 'col2', 'col3'], dtype='object')

# %%
df = pd.DataFrame([[1,444,"abc"],
         [2,222,"awe"],
         [3,333,"rgd"],
         [4,444,"kfk"]])

display(df)
index=["r1","r2","r3","r4"]
df.index=index
display(df)
# Out:
#    0    1    2
# 0  1  444  abc
# 1  2  222  awe
# 2  3  333  rgd
# 3  4  444  kfk
#     0    1    2
# r1  1  444  abc
# r2  2  222  awe
# r3  3  333  rgd
# r4  4  444  kfk

# %%
df.dtypes
# Out:
# 0     int64
# 1     int64
# 2    object
# dtype: object

# %%
df = pd.DataFrame([[1,444,"abc"],
         [2,222,"awe"],
         [3,333,"rgd"],
         [4,444,"kfk"]])

display(df)
columns = ["col1","col2","col3"]
df.columns=columns
display(df)
df.columns
df["col3"].dtype
# Out:
#    0    1    2
# 0  1  444  abc
# 1  2  222  awe
# 2  3  333  rgd
# 3  4  444  kfk
#    col1  col2 col3
# 0     1   444  abc
# 1     2   222  awe
# 2     3   333  rgd
# 3     4   444  kfk
# dtype('O')

# %%
cols=["col1","col2"]
df[cols] = df[cols].astype("category")
df.dtypes
# Out:
# col1    category
# col2    category
# col3      object
# dtype: object

# %%
df.head()
# Out:
#   col1 col2 col3
# 0    1  444  abc
# 1    2  222  awe
# 2    3  333  rgd
# 3    4  444  kfk

# %%
df.tail()
# Out:
#   col1 col2 col3
# 0    1  444  abc
# 1    2  222  awe
# 2    3  333  rgd
# 3    4  444  kfk

# %%
df.describe(include='category')
# Out:
#         col1  col2
# count      4     4
# unique     4     3
# top        1   444
# freq       1     2

# %%
df["col2"].nunique()
# Out:
# 3

# %%
df["col2"].unique()
# Out:
# [444, 222, 333]
# Categories (3, int64): [222, 333, 444]

# %%
df["col2"].min()
# Out:
# 222

# %%
df["col2"].sum()
# Out:
# np.int64(1443)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    4 non-null      int64
#  1   col2    4 non-null      int64
#  2   col3    4 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 228.0+ bytes

# %%
df["col2"].value_counts()
# Out:
# col2
# 444    2
# 222    1
# 333    1
# Name: count, dtype: int64
