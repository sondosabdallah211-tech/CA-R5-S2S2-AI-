# %% [markdown]
# Task 1

# %%
email = input("enter your email")

if email.count("@")!=1 or email.find(".")==-1:
    print("invalid email")
    
else:
    print("valid email")
# Out:
# valid email

# %%
username = email.split("@")[0]
print (username)
# Out:
# Amit_ml

# %%
Domain = email.split("@")[1] 
Domain = Domain.split(".")[0]
print(Domain)
# Out:
# gmail

# %%
if email.endswith(".com"):
    print("Commercial Domain")
    
elif email.endswith(".edu") :
    print("Educational Domain")   
    
else:
    print("Other Domain")
# Out:
# Educational Domain

# %% [markdown]
# Task 2

# %%
message = "###!!@mocleW EPGTQ!!!6789"
core = message.strip("#!@123456789 ")
print(core)
# Out:
# mocleW EPGTQ

# %%
core.split()
first_word=core.split()[0]
first_word=first_word[::-1]
print(first_word)
# Out:
# Welcom

# %%
second_word=core.split()[1]
second_word=second_word.removeprefix("E")
print(second_word)
# Out:
# PGTQ

# %%
print(first_word,second_word)
# Out:
# Welcom PGTQ

# %% [markdown]
# Task 3

# %%
message = "&&&**$gnirtS PLIO!!@1234"
core =message.strip("&*$!@1234") 
print(core)
# Out:
# gnirtS PLIO

# %%
core.split()
first_word=core.split()[0]
first_word=first_word[::-1]
print(first_word)
# Out:
# String

# %%
second_word=core.split()[1]
second_word=second_word.replace("I","E")
second_word=second_word.replace("O","U")
print(second_word)
# Out:
# PLEU

# %%
print(first_word,second_word)
# Out:
# String PLEU

# %% [markdown]
# Task 4

# %%
message = "##$$$@!yalpstcejorp EPUVT****9887"
core = message.strip("#!@$*789")
print(core)
# Out:
# yalpstcejorp EPUVT

# %%
core.split()
first_word=core.split()[0]
first_word=first_word[::-1]
print(first_word)
# Out:
# projectsplay

# %%
second_word=core.split()[1]
second_word=second_word.replace("E","A")
second_word=second_word.replace("U","O")
print(second_word)
# Out:
# APOVT

# %%
print(first_word,second_word)
# Out:
# projectsplay APOVT
